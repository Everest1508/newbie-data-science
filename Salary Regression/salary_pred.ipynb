# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix,mean_absolute_error,mean_absolute_percentage_error
import pandas as pd

# %%
df = pd.read_csv("Salary_Data.csv")
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
X= df[['YearsExperience']]
y= df['Salary']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=0)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
mean_absolute_percentage_error(y_pred=y_pred,y_true=y_test)
lr.score(X_test,y_test)
# Out:
# 0.988169515729126

# %%
import matplotlib.pyplot as plt

plt.scatter(df['YearsExperience'],y,color= 'black')
plt.plot(df['YearsExperience'],lr.predict(X),color="green")
